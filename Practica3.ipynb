# %% [markdown]
# <a href="https://colab.research.google.com/github/LeanyBM/Probabilidad-y-Estadistica/blob/main/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PROBABILIDAD Y ESTADÍSTICA**
#
# ##Unidad 1
#
# ###*Practica 3.Máximo, mínimo, rango y dispersión*
#
# ####Facilitador: Dr. José Gabriel Rodriguez Rivas
#
# ####Alumna: Leany Blanco Muñoz
#
# ![download.jpg](data:image/jpeg;base64,...)

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1= []
for i in range(100):
  numero_aleatorio= round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print (fabrica1)
# Out:
# [88.17, 55.58, 77.73, 51.07, 82.22, 90.45, 59.19, 92.16, 86.86, 64.49, 60.66, 88.4, 60.0, 61.74, 98.01, 50.64, 53.18, 52.45, 66.32, 61.32, 64.97, 86.42, 96.73, 54.26, 66.36, 64.15, 50.52, 63.98, 67.4, 99.22, 55.72, 91.02, 77.85, 70.74, 79.03, 50.55, 58.48, 96.64, 71.13, 64.26, 68.83, 98.6, 83.42, 51.59, 95.76, 63.28, 62.09, 54.89, 87.77, 52.31, 94.83, 99.55, 64.75, 96.53, 99.6, 67.9, 99.45, 84.2, 54.55, 88.34, 77.61, 83.13, 58.03, 83.81, 77.5, 99.51, 66.26, 89.78, 95.72, 97.69, 98.66, 61.27, 97.14, 55.1, 89.88, 77.69, 99.29, 75.65, 95.55, 59.39, 60.67, 78.13, 88.27, 83.36, 90.71, 86.27, 83.55, 54.49, 93.7, 62.86, 98.09, 69.88, 98.76, 70.39, 68.87, 81.58, 93.4, 82.93, 99.61, 55.14]

# %%
fabrica2= []
for i in range(100):
  numero_aleatorio2= round(random.uniform(50,100),2)
  fabrica2.append(numero_aleatorio2)
print (fabrica2)
# Out:
# [54.91, 62.7, 59.54, 88.98, 51.9, 66.39, 82.19, 83.86, 84.25, 70.9, 81.73, 52.86, 99.59, 54.56, 91.14, 59.38, 79.05, 79.79, 98.3, 55.83, 68.98, 81.92, 54.92, 70.6, 85.19, 56.03, 58.4, 69.79, 91.38, 62.68, 56.61, 57.89, 65.19, 86.2, 61.08, 71.12, 88.66, 90.05, 73.53, 92.91, 63.04, 61.39, 80.74, 51.69, 61.57, 64.05, 53.33, 58.32, 60.01, 52.17, 73.43, 85.4, 61.46, 82.22, 78.57, 86.04, 87.48, 82.55, 80.27, 90.11, 70.79, 78.31, 93.32, 89.79, 81.55, 57.03, 66.82, 85.7, 84.93, 86.67, 57.57, 68.72, 87.04, 60.97, 73.05, 50.14, 90.1, 80.4, 69.87, 71.12, 81.46, 59.78, 72.81, 75.2, 58.97, 61.07, 90.09, 58.27, 93.95, 50.26, 84.15, 82.57, 59.65, 90.28, 77.78, 93.22, 58.04, 92.16, 95.13, 60.87]

# %% [markdown]
# Maximo minimo, rango

# %%
maximo1=max(fabrica1)
minimo1=min(fabrica1)
rango1=maximo1-minimo1
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
print("Estadistica descriptiva en la Fábrica 1\n", "Media= ",media1,
      "\n Mediana= ",mediana1, "Moda= ",moda1, "\n Máximo= ", maximo1, "\n Mínimo", minimo1,"\n Rango= ", rango1)
# Out:
# Estadistica descriptiva en la Fábrica 1
#  Media=  76.3763
#  Mediana=  77.71000000000001 Moda=  88.17
#  Máximo=  99.61
#  Mínimo 50.52
#  Rango=  49.089999999999996

# %%
maximo2=max(fabrica2)
minimo2=min(fabrica2)
rango2=maximo2-minimo2
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
print("Estadistica descriptiva en la Fábrica 2\n", "Media= ",media2,
      "\n Mediana= ",mediana2, "Moda= ",moda2, "\n Máximo= ", maximo2, "\n Mínimo", minimo2,"\n Rango= ", rango2)
# Out:
# Estadistica descriptiva en la Fábrica 2
#  Media=  73.1442
#  Mediana=  72.93 Moda=  71.12
#  Máximo=  99.59
#  Mínimo 50.14
#  Rango=  49.45

# %% [markdown]
# Dispersion de los datos

# %%
desviacion_estandar_fabrica1=stdev(fabrica1)
print(desviacion_estandar_fabrica1)
# Out:
# 16.33054204071115

# %%
desviacion_estandar_fabrica2=stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 13.835776723240135

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica1,bins=10, alpha=0.2, color="b", edgecolor="black")
plt.axvline(media1, color="b", linestyle="dashed", linewidth=2, label=f"Media={media1:.2f}")
plt.axvline(mediana1, color="r", linestyle="dashed",linewidth=2, label=f"Mediana={mediana1:.2f}")
plt.axvline(moda1, color="y", linestyle="dashed",linewidth=2, label=f"Moda={moda1:.2f}")
plt.axvline(media1- desviacion_estandar_fabrica1, color="black", linestyle="dashed", linewidth=2, label=f"Desviacion estandar={desviacion_estandar_fabrica1:.2f}")
plt.axvline(media1+ desviacion_estandar_fabrica1, color="black", linestyle="dashed", linewidth=2)
plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.title("Producción diaria de la Fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica2,bins=10, alpha=0.2, color="b", edgecolor="black")
plt.axvline(media2, color="b", linestyle="dashed", linewidth=2, label=f"Media={media2:.2f}")
plt.axvline(mediana2, color="r", linestyle="dashed",linewidth=2, label=f"Mediana={mediana2:.2f}")
plt.axvline(moda2, color="y", linestyle="dashed",linewidth=2, label=f"Moda={moda2:.2f}")
plt.axvline(media2- desviacion_estandar_fabrica2, color="black", linestyle="dashed",
            linewidth=2, label=f"Desviacion estandar={desviacion_estandar_fabrica2:.2f}")
plt.axvline(media2+ desviacion_estandar_fabrica2, color="black", linestyle="dashed", linewidth=2)
plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.title("Producción diaria de la Fábrica 2")
plt.legend()
plt.show()
