# %% [markdown]
# <a href="https://colab.research.google.com/github/LeanyBM/Probabilidad-y-Estadistica/blob/main/practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PROBABILIDAD Y ESTADÍSTICA**
#
# ##Unidad 1
#
# ###*Practica 4.Tabla de frecuencia*
#
# ####Facilitador: Dr. José Gabriel Rodriguez Rivas
#
# ####Alumna: Leany Blanco Muñoz

# %%
#basado en el LIBRO de estadistica  para administracion pagina 12
#lista vacia que representa la edad de 100 personas
import random
edades= []
#Ciclo para generar 100 numeros aleatorios que representan la edad de las personas
for i in range (100):
  #generamos un numero aleatorio con la funcion randit y lo guardamos en la variable
  #numero_aleatorio
  numero_aleatorio = random.randint(18,70)
  #Agregamos el numero aleatorio a la lista de valores
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [51, 29, 24, 63, 24, 30, 26, 20, 22, 52, 34, 31, 54, 51, 19, 18, 31, 67, 31, 51, 26, 39, 19, 38, 42, 21, 23, 31, 31, 51, 68, 70, 66, 27, 25, 60, 48, 48, 23, 64, 57, 43, 20, 70, 41, 57, 34, 55, 35, 69, 34, 49, 43, 41, 27, 63, 19, 52, 56, 47, 18, 50, 70, 41, 51, 34, 39, 44, 36, 40, 39, 54, 19, 31, 50, 60, 56, 50, 32, 51, 23, 32, 55, 59, 31, 39, 44, 31, 45, 63, 51, 70, 28, 29, 66, 70, 50, 54, 31, 44]

# %%
import pandas as pd

# %%
#Crear un DataFrame de pandas con los números aleatorios
df=pd.DataFrame(edades,columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    51
# 1    29
# 2    24
# 3    63
# 4    24

# %%
#Calcular la tabla de distribución de frecuencias
tabla_frecuencias=df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns=['Edad','Frecuencia']
tabla_frecuencias=tabla_frecuencias.sort_values(by='Edad')

#Imprimir la tabla de distribucion de frecuencias
print("Tabla de Distribución de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 24    18           2
# 6     19           4
# 22    20           2
# 36    21           1
# 38    22           1
# 9     23           3
# 23    24           2
# 43    25           1
# 26    26           2
# 12    27           2
# 44    28           1
# 20    29           2
# 32    30           1
# 0     31           9
# 15    32           2
# 5     34           4
# 37    35           1
# 31    36           1
# 41    38           1
# 3     39           4
# 30    40           1
# 10    41           3
# 42    42           1
# 17    43           2
# 8     44           3
# 28    45           1
# 33    47           1
# 14    48           2
# 35    49           1
# 4     50           4
# 1     51           7
# 25    52           2
# 7     54           3
# 18    55           2
# 19    56           2
# 16    57           2
# 29    59           1
# 13    60           2
# 11    63           3
# 40    64           1
# 21    66           2
# 39    67           1
# 27    68           1
# 34    69           1
# 2     70           5

# %%
tabla_frecuencias["Frec Relativa"] = tabla_frecuencias["Frecuencia"]/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 24    18           2           0.02
# 6     19           4           0.04
# 22    20           2           0.02
# 36    21           1           0.01
# 38    22           1           0.01
# 9     23           3           0.03
# 23    24           2           0.02
# 43    25           1           0.01
# 26    26           2           0.02
# 12    27           2           0.02
# 44    28           1           0.01
# 20    29           2           0.02
# 32    30           1           0.01
# 0     31           9           0.09
# 15    32           2           0.02
# 5     34           4           0.04
# 37    35           1           0.01
# 31    36           1           0.01
# 41    38           1           0.01
# 3     39           4           0.04
# 30    40           1           0.01
# 10    41           3           0.03
# 42    42           1           0.01
# 17    43           2           0.02
# 8     44           3           0.03
# 28    45           1           0.01
# 33    47           1           0.01
# 14    48           2           0.02
# 35    49           1           0.01
# 4     50           4           0.04
# 1     51           7           0.07
# 25    52           2           0.02
# 7     54           3           0.03
# 18    55           2           0.02
# 19    56           2           0.02
# 16    57           2           0.02
# 29    59           1           0.01
# 13    60           2           0.02
# 11    63           3           0.03
# 40    64           1           0.01
# 21    66           2           0.02
# 39    67           1           0.01
# 27    68           1           0.01
# 34    69           1           0.01
# 2     70           5           0.05

# %%
tabla_frecuencias["Frec Porcentual"] = tabla_frecuencias["Frecuencia"]/100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 24    18           2           0.02              2.0
# 6     19           4           0.04              4.0
# 22    20           2           0.02              2.0
# 36    21           1           0.01              1.0
# 38    22           1           0.01              1.0
# 9     23           3           0.03              3.0
# 23    24           2           0.02              2.0
# 43    25           1           0.01              1.0
# 26    26           2           0.02              2.0
# 12    27           2           0.02              2.0
# 44    28           1           0.01              1.0
# 20    29           2           0.02              2.0
# 32    30           1           0.01              1.0
# 0     31           9           0.09              9.0
# 15    32           2           0.02              2.0
# 5     34           4           0.04              4.0
# 37    35           1           0.01              1.0
# 31    36           1           0.01              1.0
# 41    38           1           0.01              1.0
# 3     39           4           0.04              4.0
# 30    40           1           0.01              1.0
# 10    41           3           0.03              3.0
# 42    42           1           0.01              1.0
# 17    43           2           0.02              2.0
# 8     44           3           0.03              3.0
# 28    45           1           0.01              1.0
# 33    47           1           0.01              1.0
# 14    48           2           0.02              2.0
# 35    49           1           0.01              1.0
# 4     50           4           0.04              4.0
# 1     51           7           0.07              7.0
# 25    52           2           0.02              2.0
# 7     54           3           0.03              3.0
# 18    55           2           0.02              2.0
# 19    56           2           0.02              2.0
# 16    57           2           0.02              2.0
# 29    59           1           0.01              1.0
# 13    60           2           0.02              2.0
# 11    63           3           0.03              3.0
# 40    64           1           0.01              1.0
# 21    66           2           0.02              2.0
# 39    67           1           0.01              1.0
# 27    68           1           0.01              1.0
# 34    69           1           0.01              1.0
# 2     70           5           0.05              5.0

# %%
tabla_frecuencias ["Frec Acumulada"] = tabla_frecuencias["Frecuencia"].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 24    18           2           0.02              2.0               2
# 6     19           4           0.04              4.0               6
# 22    20           2           0.02              2.0               8
# 36    21           1           0.01              1.0               9
# 38    22           1           0.01              1.0              10
# 9     23           3           0.03              3.0              13
# 23    24           2           0.02              2.0              15
# 43    25           1           0.01              1.0              16
# 26    26           2           0.02              2.0              18
# 12    27           2           0.02              2.0              20
# 44    28           1           0.01              1.0              21
# 20    29           2           0.02              2.0              23
# 32    30           1           0.01              1.0              24
# 0     31           9           0.09              9.0              33
# 15    32           2           0.02              2.0              35
# 5     34           4           0.04              4.0              39
# 37    35           1           0.01              1.0              40
# 31    36           1           0.01              1.0              41
# 41    38           1           0.01              1.0              42
# 3     39           4           0.04              4.0              46
# 30    40           1           0.01              1.0              47
# 10    41           3           0.03              3.0              50
# 42    42           1           0.01              1.0              51
# 17    43           2           0.02              2.0              53
# 8     44           3           0.03              3.0              56
# 28    45           1           0.01              1.0              57
# 33    47           1           0.01              1.0              58
# 14    48           2           0.02              2.0              60
# 35    49           1           0.01              1.0              61
# 4     50           4           0.04              4.0              65
# 1     51           7           0.07              7.0              72
# 25    52           2           0.02              2.0              74
# 7     54           3           0.03              3.0              77
# 18    55           2           0.02              2.0              79
# 19    56           2           0.02              2.0              81
# 16    57           2           0.02              2.0              83
# 29    59           1           0.01              1.0              84
# 13    60           2           0.02              2.0              86
# 11    63           3           0.03              3.0              89
# 40    64           1           0.01              1.0              90
# 21    66           2           0.02              2.0              92
# 39    67           1           0.01              1.0              93
# 27    68           1           0.01              1.0              94
# 34    69           1           0.01              1.0              95
# 2     70           5           0.05              5.0             100

# %% [markdown]
# #Regla de sturges
#
# c=1+log2(N)
# donde N es el tamaño de la muestra

# %%
import math

# %%
print (edades)
# Out:
# [51, 29, 24, 63, 24, 30, 26, 20, 22, 52, 34, 31, 54, 51, 19, 18, 31, 67, 31, 51, 26, 39, 19, 38, 42, 21, 23, 31, 31, 51, 68, 70, 66, 27, 25, 60, 48, 48, 23, 64, 57, 43, 20, 70, 41, 57, 34, 55, 35, 69, 34, 49, 43, 41, 27, 63, 19, 52, 56, 47, 18, 50, 70, 41, 51, 34, 39, 44, 36, 40, 39, 54, 19, 31, 50, 60, 56, 50, 32, 51, 23, 32, 55, 59, 31, 39, 44, 31, 45, 63, 51, 70, 28, 29, 66, 70, 50, 54, 31, 44]

# %%
df=pd.DataFrame({"Edad": edades })
df
# Out:
#     Edad
# 0     51
# 1     29
# 2     24
# 3     63
# 4     24
# ..   ...
# 95    70
# 96    50
# 97    54
# 98    31
# 99    44
#
# [100 rows x 1 columns]

# %%
n= len(edades)
K= int(1+math.log2(n))
print("Valor de n = ", n, "\nNúmero de intervalos = ", K)
# Out:
# Valor de n =  100
# Número de intervalos =  7

# %%
tabla_frecuencia=pd.cut( df['Edad'],bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns=['Clase','Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (47.714, 55.143]    21
# 1  (25.429, 32.857]    19
# 2  (17.947, 25.429]    16
# 3    (62.571, 70.0]    14
# 4  (32.857, 40.286]    12
# 5  (40.286, 47.714]    11
# 6  (55.143, 62.571]     7

# %%
#Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia=tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 2  (17.947, 25.429]    16
# 1  (25.429, 32.857]    19
# 4  (32.857, 40.286]    12
# 5  (40.286, 47.714]    11
# 0  (47.714, 55.143]    21
# 6  (55.143, 62.571]     7
# 3    (62.571, 70.0]    14

# %%
#Generar columnas siguientes
tabla_frecuencia['Frec Rel']=tabla_frecuencia['Frec'] /n
tabla_frecuencia['Frec Porc']=tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac']=tabla_frecuencia['Frec Porc'].cumsum()

#Mostrar
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 2  (17.947, 25.429]    16      0.16       16.0       16         0.16
# 1  (25.429, 32.857]    19      0.19       19.0       35         0.35
# 4  (32.857, 40.286]    12      0.12       12.0       47         0.47
# 5  (40.286, 47.714]    11      0.11       11.0       58         0.58
# 0  (47.714, 55.143]    21      0.21       21.0       79         0.79
# 6  (55.143, 62.571]     7      0.07        7.0       86         0.86
# 3    (62.571, 70.0]    14      0.14       14.0      100         1.00
#
#    Frec Porc Ac
# 2          16.0
# 1          35.0
# 4          47.0
# 5          58.0
# 0          79.0
# 6          86.0
# 3         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades,alpha =0.5,bins=20)
plt.title("Histograma basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma basado en la funcion de matplotlib con valores estandar')

# %%
#crear un histograma basado en la tabla de frecuencia
plt.hist(df["Edad"] , bins=K, alpha=0.5)
plt.title("Histograma de edades basado en la regla de Sturges")
plt.xlabel("Edades")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #**Práctica 5. Diagrama de cajas y bigotes**

# %%
import random
edades2= []
for i in range (100):
  numero_aleatorio = random.randint(20,87)
  edades2.append(numero_aleatorio)
print(edades2)
# Out:
# [37, 52, 71, 27, 33, 80, 24, 40, 83, 32, 77, 27, 86, 30, 70, 47, 48, 52, 69, 74, 48, 42, 71, 34, 84, 20, 54, 57, 80, 85, 61, 56, 35, 34, 83, 71, 24, 20, 71, 31, 62, 44, 57, 37, 24, 77, 36, 25, 77, 61, 75, 74, 33, 67, 63, 37, 62, 55, 63, 48, 37, 34, 38, 37, 37, 33, 62, 37, 27, 23, 85, 49, 24, 50, 35, 61, 72, 28, 61, 72, 24, 69, 75, 28, 72, 27, 66, 32, 84, 69, 45, 46, 34, 45, 36, 54, 44, 64, 77, 29]

# %%
fig,(ax1, ax2)=plt.subplots(nrows=1,ncols=2,figsize=(9,4))
bplot1= ax1.boxplot(edades,
                  vert=True, #vertical box aligment
                  patch_artist=True) #fill with color
ax1.set_title("Edades Encuesta 1")

bplot1= ax2.boxplot(edades2,
                  vert=True, #vertical box aligment
                  patch_artist=True) #fill width color
ax2.set_title("Edades Encuesta 2")
plt.show()

# %%
edades2.append(130)
#ya tengo mi lista de edades le vamos a agregar la edad de 130

# %%
fig,(ax1, ax2)=plt.subplots(nrows=1,ncols=2,figsize=(9,4))
bplot1= ax1.boxplot(edades,
                  vert=True, #vertical box aligment
                  patch_artist=True) #fill with color
ax1.set_title("Edades Encuesta 1")

bplot1= ax2.boxplot(edades2,
                  vert=True, #vertical box aligment
                  patch_artist=True) #fill width color
ax2.set_title("Edades Encuesta 2")
plt.show()
